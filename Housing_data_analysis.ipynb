# %%
import pandas as pd

# %%
df=pd.read_csv('Housing+Data.csv')

# %%
df.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.shape
# Out:
# (13549, 6)

# %%
df.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# dtype: int64

# %%
df.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# dtype: int64

# %%
df['no_of_crimes']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 13544   NaN
# 13545   NaN
# 13546   NaN
# 13547   NaN
# 13548   NaN
# Name: no_of_crimes, Length: 13549, dtype: float64

# %%
df.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
df['no_of_crimes'].fillna(df['no_of_crimes'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# date              0
# area              0
# average_price     0
# code              0
# houses_sold      94
# no_of_crimes      0
# dtype: int64

# %% [markdown]
# # visualize the NULL values in the dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plot

# %%
sns.heatmap(df.isnull())
plot.show()

# %% [markdown]
# #Q1 convert th datatype of 'date' columns to 'date-format' format

# %%
df.head()
# Out:
#        date            area  average_price       code  houses_sold  \
# 0  1/1/1995  city of london          91449  E09000001         17.0
# 1  2/1/1995  city of london          82203  E09000001          7.0
# 2  3/1/1995  city of london          79121  E09000001         14.0
# 3  4/1/1995  city of london          77101  E09000001          7.0
# 4  5/1/1995  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0   2158.352063
# 1   2158.352063
# 2   2158.352063
# 3   2158.352063
# 4   2158.352063

# %%
df.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# dtype: object

# %%
df['date']=pd.to_datetime(df.date)

# %%
df.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# dtype: object

# %% [markdown]
# #Q2 add a column 'year' in the dataframe, which contains years only

# %%
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0   2158.352063
# 1   2158.352063
# 2   2158.352063
# 3   2158.352063
# 4   2158.352063

# %%
df['Year']=df['date'].dt.year

# %%
df
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  Year
# 0       2158.352063  1995
# 1       2158.352063  1995
# ...

# %% [markdown]
# #Q2 add the month columns as 2nd column which contains only the months

# %%
df.insert(1,'month',df['date'].dt.month,True)

# %%
df.head()
# Out:
#         date  month            area  month  average_price       code  \
# 0 1995-01-01      1  city of london      1          91449  E09000001
# 1 1995-02-01      2  city of london      2          82203  E09000001
# 2 1995-03-01      3  city of london      3          79121  E09000001
# 3 1995-04-01      4  city of london      4          77101  E09000001
# 4 1995-05-01      5  city of london      5          84409  E09000001
#
#    houses_sold  no_of_crimes  Year
# 0         17.0   2158.352063  1995
# 1          7.0   2158.352063  1995
# 2         14.0   2158.352063  1995
# 3          7.0   2158.352063  1995
# 4         10.0   2158.352063  1995

# %% [markdown]
# #Q3 Remove the month and year column from the dataframe

# %%
df.drop(['month','Year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0   2158.352063
# 1   2158.352063
# 2   2158.352063
# 3   2158.352063
# 4   2158.352063

# %% [markdown]
# #q4 show all the records where 'No. of crimes ' is 0 and how many sunch records are there

# %%
df[df['no_of_crimes']==0]
# Out:
#           date            area  average_price       code  houses_sold  \
# 72  2001-01-01  city of london         284262  E09000001         24.0
# 73  2001-02-01  city of london         198137  E09000001         37.0
# 74  2001-03-01  city of london         189033  E09000001         44.0
# 75  2001-04-01  city of london         205494  E09000001         38.0
# 76  2001-05-01  city of london         223459  E09000001         30.0
# ..         ...             ...            ...        ...          ...
# 178 2009-11-01  city of london         397909  E09000001         11.0
# 179 2009-12-01  city of london         411955  E09000001         16.0
# 180 2010-01-01  city of london         464436  E09000001         20.0
# 181 2010-02-01  city of london         490525  E09000001          9.0
# 182 2010-03-01  city of london         498241  E09000001         15.0
#
#      no_of_crimes
# 72            0.0
# 73            0.0
# 74            0.0
# 75            0.0
# 76            0.0
# ...

# %%
len(df[df['no_of_crimes']==0])
# Out:
# 104

# %% [markdown]
# #q5 what is the maximum and minimum 'average_price' per year in england

# %%
df.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes
# 0   2158.352063
# 1   2158.352063
# 2   2158.352063
# 3   2158.352063
# 4   2158.352063

# %%
df1=df[df['area']=='england']

# %%
df1.head()
# Out:
#             date     area  average_price       code  houses_sold  no_of_crimes
# 13248 1995-01-01  england          53203  E92000001      47639.0   2158.352063
# 13249 1995-02-01  england          53096  E92000001      47880.0   2158.352063
# 13250 1995-03-01  england          53201  E92000001      67025.0   2158.352063
# 13251 1995-04-01  england          53591  E92000001      56925.0   2158.352063
# 13252 1995-05-01  england          53678  E92000001      64192.0   2158.352063

# %%
df1['year']=df1.date.dt.year
# Out:
# <ipython-input-87-4dba8e94f297>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['year']=df1.date.dt.year

# %%
df1.head()
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
#
#        no_of_crimes  year
# 13248   2158.352063  1995
# 13249   2158.352063  1995
# 13250   2158.352063  1995
# 13251   2158.352063  1995
# 13252   2158.352063  1995

# %%
df1.groupby('year').average_price.mean()
# Out:
# year
# 1995     53322.416667
# 1996     54151.500000
# 1997     59160.666667
# 1998     64301.666667
# 1999     70070.750000
# 2000     80814.333333
# 2001     90306.750000
# 2002    107981.500000
# 2003    130218.583333
# 2004    152314.416667
# 2005    163570.000000
# 2006    174351.500000
# 2007    190025.583333
# 2008    182379.916667
# 2009    166558.666667
# 2010    177472.666667
# 2011    175230.000000
# 2012    177488.000000
# 2013    182581.416667
# 2014    197771.083333
# 2015    211174.750000
# 2016    227337.166667
# 2017    238161.166667
# 2018    245018.333333
# 2019    247101.083333
# 2020    247355.000000
# Name: average_price, dtype: float64

# %%
df1.groupby('year').average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %% [markdown]
# #q6 maximum and minimum no. of crimes in each area

# %%
df.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes
# 0   2158.352063
# 1   2158.352063

# %%
df.groupby('area').no_of_crimes.min().sort_values(ascending=True)
# Out:
# area
# city of london               0.000000
# kingston upon thames       692.000000
# richmond upon thames       700.000000
# sutton                     787.000000
# merton                     819.000000
# bexley                     860.000000
# harrow                     937.000000
# havering                  1130.000000
# barking and dagenham      1217.000000
# hammersmith and fulham    1323.000000
# kensington and chelsea    1347.000000
# bromley                   1441.000000
# hillingdon                1445.000000
# redbridge                 1487.000000
# greenwich                 1513.000000
# hounslow                  1529.000000
# haringey                  1536.000000
# waltham forest            1575.000000
# wandsworth                1582.000000
# enfield                   1635.000000
# tower hamlets             1646.000000
# lewisham                  1675.000000
# barnet                    1703.000000
# brent                     1850.000000
# ...

# %% [markdown]
# #q7 show the total count of records of each area , where average price is less than 100000

# %%
df[df['average_price']<100000].area.value_counts()
# Out:
# area
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# lambeth                  41
# hounslow                 41
# brent                    40
# london                   39
# merton                   35
# haringey                 33
# bromley                  33
# inner london             31
# ...
